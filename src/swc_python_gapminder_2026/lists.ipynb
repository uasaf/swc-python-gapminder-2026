# %%
pressures = [.273, .275, .277, .275, .268]
print('pressures',pressures)
print('length', len(pressures))
# Out:
# pressures [0.273, 0.275, 0.277, 0.275, 0.268]
# length 5

# %%
pressures[4] = -.001
print(pressures)
# Out:
# [0.273, 0.275, 0.277, 0.275, -0.001]

# %%
primes = [2,3,5]
print("primes is initiallly", primes)
primes.append(7)
print("primes has become", primes)
# Out:
# primes is initiallly [2, 3, 5]
# primes has become [2, 3, 5, 7]

# %%
primes.extend([11,13,17])
print(primes)
# Out:
# [2, 3, 5, 7, 11, 13, 17]

# %%
primes.append(21)
print(primes)
del primes[7]
print(primes)
# Out:
# [2, 3, 5, 7, 11, 13, 17, 21]
# [2, 3, 5, 7, 11, 13, 17]

# %%
goals = [1,"create a goals list", 2, "add items to goals list"]
print(goals)
# Out:
# [1, 'create a goals list', 2, 'add items to goals list']

# %%
values = []
values.append(1)
values.append(3)
values.append(5)
print('first time::', values)
values = values[1:3]
print('second time:', values)
# Out:
# first time:: [1, 3, 5]
# second time: [3, 5]
