# %% [markdown]
# # Python SWC workshop September 2026
#
# Steve Forsyth

# %%
age = 61
first_name = "Steve"
print(first_name, "is", age, "years old")
print('hello world')
# Out:
# Steve is 61 years old
# hello world

# %%
last_name = 'Forsyth'
print(last_name)
# Out:
# Forsyth

# %%
age_in_3 = age + 3
print(first_name, "will be", age_in_3, "in three years")
# Out:
# Steve will be 64 in three years

# %%
first_name[0]
# Out:
# 'S'

# %%
# Stop is exclusive, so to get the third character included you need to use 3.
first_name[0:3]
# Out:
# 'Ste'

# %%
import math

print('pi is', math.pi)
# Out:
# pi is 3.141592653589793

# %%
from math import cos,pi

print('pi is', pi)
print(cos(pi))
# Out:
# pi is 3.141592653589793
# -1.0

# %%
import math as m
m.pi
# Out:
# 3.141592653589793

# %%
import random as r

r.choice('ACTTGCTTGAC')
# Out:
# 'C'
